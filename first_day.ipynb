# %% [markdown]
# $python is a programming language$

# %%
a=10
b=2000000000
c=a+b
c
# Out:
# 2000000010

# %% [markdown]
# # python
# ## python
# ### python

# %% [markdown]
# - hello
#     - hello
#         - hello

# %%
import time
time.sleep(10)
print("hello world")
# Out:
# hello world

# %% [markdown]
# # #Identifiers

# %% [markdown]
# - combination of alphabets and numbers & ' _ '
#     - variables
#     - functions
#     - classes

# %%
a1=60
a_ = 30
_f = 34
print(a1)
print(a_)
print(_f)

# %% [markdown]
# # #Keywords
#
# - reserve words for python this words which should not used as identifiers
#     - eg if, else, while, for, or, and etc 35 keywords

# %%
import keyword
keyword.kwlist

# %%
import keyword
keyword.kwlist

len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # #Variables

# %% [markdown]
# - variables are identifiers used to store data

# %%
 #eg 
a = 9 
b = 22
b = 4

# %% [markdown]
# # #Data types
# - integers(whole number without decimal),
#
# -  float(decimal),
#
# -  string(text data),
#
# -  boolean(true false)
#
# - two types of data = num capa

# %%
a1 = 23.33
b1 = 70
c1 = 45.00
d1 = "Naresh"
d_1 = '25'
e1 = True
f1 = print(type(a1))
print(type(b1))
print(type(c1))
print(type(d1))
print(type(d_1))
print(type(e1))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
 #pwd present working dir

# %%
x1 = 34
x2 = 35
x1 == x2

# %%
a = 16
b = 12
a 
b

# %% [markdown]
# # #Data typecasting

# %% [markdown]
# - changing a data types
# - automatically understanding data type
# - we can convert float into integer
# - if number in string we can convert into int and float
# - in string have float value like "25.55" we cannot convert into integer but convert into float
# -

# %%
x1 = 23
x1

# %%
x2 = float(x1)

# %%
x2

# %%
type(x2)

# %%
x1

# %%
type(x1)

# %%
x1 = float(x1)

# %%
type(x1)

# %%
a1 = 23
str(a1)

# %%
a2 = str(a1)

# %%
a2

# %%
type(a2)

# %%
y1 = 34.44
type(y1)

# %%
 y2 = int(y1)

# %%
type(y2)

# %%
z1 = abhijeet

# %%
d1 = "23.33"

# %%
d1 = float(d1)

# %%
d1

# %%
int(d1)

# %%
f1 = '33.33'
f2 = float(f1)

# %%
f3 = int(f2)

# %%
f3

# %%
f1

# %%
f1 = float(f1)

# %%
f1

# %%
#convert this marks into integer
marks = "72.55"

# %%
marks

# %%
marks = float(marks)

# %%
marks = int(marks)

# %%
marks

# %% [markdown]
# # #Comments

# %%
#hello single line comment
'''  
this is multi 
 line comment
 '''

# %% [markdown]
# # #String
# - set of alphabets and words

# %%
a1  = "hello everyone"
len(a1)

# %%
a1[5]
a1[-5]

# %% [markdown]
# ## string indexing
#
# - indxing a every character of string
# - positive left to right
# - neg right to left

# %%
name = "abhijeet"
name[5]

# %% [markdown]
# ## string slicing
# - (string name)[start : end]
#
# - end position should be 1 extra

# %%
shiv = "maha dev"

# %%
shiv[0: 5]

# %%
a1 = "hello Everyone"

# %%
a1[0:14]

# %%
a1[2:11]

# %% [markdown]
# ### - step size
# - it skip 2 character if we give step size 2  like strName [0:10:2]

# %%
myname = "abhijeet"

# %%
myname[0:8:2]

# %%
myname[0:]  #it give start to end

# %%
myname[6:]

# %%
myname[:]   #it give start to end

# %%
myname[::]  #it give start to end

# %%
a1[::2] # it skip 2 character if we give step size 2

# %%
a1

# %%
a1[-8:-3]

# %%
a1[-8:-3:2]

# %%
a1[-14:-9]

# %%
a1[:-9]

# %%
a1[-8:]

# %%
a1[10:5:-1]  # -1 is for reverse direction

# %%
a1[-4:-9:-1]

# %%
a1[14::-1]

# %%
a1[-1:-15:-1]

# %%
a1[::-1] #reverse asset

# %%
a1[::1] #forward assets

# %%
a2 = "apple banana kiwi orange"  #hw
a2

# %%
# print all fruits  both -1 1
print(a2[0:6])
print(a2[5::-1])

# %% [markdown]
# ## string methods
# - strings are immutable
# - methods are basically function
# - tab suggesion of function
# - shift + tab to get info of the function

# %%
a1 = "Hello Everyone"

# %%
a1.upper()

# %%
a1.lower()

# %%
a1.title()

# %%
a1 = a1.upper()

# %%
a1.capitalize()

# %%
a1.count('E')

# %%
a1.index("l")

# %%
a1

# %%
a1.replace("Hello", 'hi')  #replace

# %%
a1.split(" ")  #split the char word info  we give from space 
               # by default it split with space given

# %%
a1.split('o')

# %%
a1.split('e')

# %%
a4 = "     hello abhijeet    "

# %%
a4

# %%
a4.strip()

# %%
a4.lstrip(' ')

# %%
a4.rstrip(" ")

# %%
a5 = '******hello*****everyone'

# %%
a5

# %%
a5.strip("*")

# %%
a5.rstrip('*')

# %%
a5.lstrip('*')

# %% [markdown]
# ## string concination

# %%
"data" +' ' +"analyst"

# %% [markdown]
# ## print   -inbuild fun

# %%
b1 = 5
print(b1)

# %%
b2 = 9
b3 = 'hello'
b4 = 5
print(b2,b3,b4,'hi',23*34, sep="|")  #seperatorz    by default space

# %%
print(b2)
print(b3)
print(b4)

# %%
print(b2, end=' ')
print(b3, end=' ')
print(b4,)

# %%
#we can store simultaneously
c1,c2,c3,c4 = 12,23,34,33

# %%
c1

# %%
c2

# %%
c3

# %%
c4

# %%
print(22,end='-')
print('jan',end='-')
print(2026)
